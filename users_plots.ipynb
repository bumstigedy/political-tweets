# %%
import pandas as pd
import seaborn as sns

# %%
df_users=pd.read_csv('/users/bumst/code/sql_capstone/users.csv')

# %%
df_users.head()
# Out:
#                             created_at  \
# 0  1970-01-01 00:00:01.417384037+00:00
# 1  1970-01-01 00:00:01.240239576+00:00
# 2  1970-01-01 00:00:01.366837593+00:00
# 3  1970-01-01 00:00:01.300739574+00:00
# 4  1970-01-01 00:00:01.294329706+00:00
#
#                                          description  favourites_count  \
# 0  Official Twitter page of Alaska Governor Bill ...               115
# 1  U.S. Senator from Minnesota. Follows, Retweets...                24
# 2  Congressman for Maryland's 4th Congressional D...                90
# 3  Husband of 43 yrs, Dad of 4, Papaw of 6. Lifel...               440
# 4  I am proud to represent the 8th Congressional ...                12
#
#    followers_count  friends_count          id           location  \
# 0             5870            550  2915095729             Alaska
# 1           170717          91751    33537967                NaN
# 2             6067            369  1378000346  Mitchellville, MD
# ...

# %%
sns.distplot(df_users.followers_count)
# Out:
# C:\Users\bumst\AppData\Roaming\Python\Python38\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='followers_count', ylabel='Density'>

# %%
sns.distplot(df_users.favourites_count)
# Out:
# C:\Users\bumst\AppData\Roaming\Python\Python38\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='favourites_count', ylabel='Density'>

# %%
sns.distplot(df_users.friends_count)
# Out:
# C:\Users\bumst\AppData\Roaming\Python\Python38\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='friends_count', ylabel='Density'>

# %%
sns.scatterplot(x=df_users.friends_count,y=df_users.favourites_count)
# Out:
# <AxesSubplot:xlabel='friends_count', ylabel='favourites_count'>

# %%
sns.scatterplot(x=df_users.followers_count,y=df_users.favourites_count)
# Out:
# <AxesSubplot:xlabel='followers_count', ylabel='favourites_count'>
